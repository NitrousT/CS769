# %% [markdown]
# **Prior to executing the code files on Colab make sure that you're connected to the GPU VM or in case of local setup make sure you have an nvidia GPU with appropiate CUDA driver installed.**

# %%
# !nvidia-smi
# Out:
# Sat Apr 23 19:18:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Go the desired directory
# %cd /content/GPU-Multi-Agent-Traj-Opt/8_robots_square/
# !ls
# Out:
# /content/GPU-Multi-Agent-Traj-Opt/8_robots_square
# bernstein_coeff_order10_arbitinterval.py  matrix_computation
# comparison_data				  new_plot.py
# init_final_pos.py			  optim_cupy.py
# main_8robot.py				  wrapper_8_robots.py

# %% [markdown]
# **Run the following cell to generate the different matrices and inverses required for multi-agent trajectory optimization**

# %%
# %cd matrix_computation/
# !python inverse_matrix_computation.py
# Out:
# [Errno 2] No such file or directory: 'matrix_computation/'
# /content/GPU-Multi-Agent-Traj-Opt/8_robots_square/matrix_computation

# %% [markdown]
# **Then run the main file to create the trajectory mat files for different agents**
#
# You will have to change the name of the directory/folder manually below

# %%
# %cd /content/GPU-Multi-Agent-Traj-Opt/8_robots_square/
# !python main_8robot.py
# Out:
# /content/GPU-Multi-Agent-Traj-Opt/8_robots_square
# Loading Matrices
# Starting Actual Computation
# 0.010673684264656647 0.006715010436541435 0.0002520507699089857
# comp time for 1 benchmarks = 0.574613094329834

# %% [markdown]
# **The trajectories can be visualized by running the plot file**

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 10] # Adjust the Height and Width 
plt.rcParams['figure.dpi'] = 100   # and DPI to your liking
# %run new_plot.py
